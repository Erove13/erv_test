# %%
import pandas as pd

df_lego_inicial = pd.read_csv('Set_Lanzanzados.csv')

df_lego_inicial.head()
# Out:
# C:\Users\Ema\AppData\Local\Temp\ipykernel_12692\3189011234.py:3: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_lego_inicial = pd.read_csv('Set_Lanzanzados.csv')
#    SetID Number  Variant  YearFrom Category                   Theme  \
# 0  22667      1        1      1965   Normal               Samsonite
# 1  22683      1        3      1967   Normal               Samsonite
# 2   7465      1        7      1973   Normal  Universal Building Set
# 3   7693      1        8      1970   Normal               Minitalia
# 4  22697      1        9      1969   Normal                  System
#
#   ThemeGroup   Subtheme                                 SetName Image  ...  \
# 0    Vintage  Basic Set                                   Gears     X  ...
# 1    Vintage  Basic Set  Promotional Set No. 1 (Kraft Velveeta)     X  ...
# 2      Basic        NaN                               Basic Set     X  ...
# 3    Vintage        NaN                         Small house set     X  ...
# 4      Basic  Basic Set           Set No 1 - Quaker/Life Cereal   NaN  ...
#
#   WantedPriority  Unnamed: 49  Flag2  Flag3  Flag4 Flag5 Flag6  Flag7  Flag8  \
# 0              0          NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 1              0          NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 2              0          NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 3              0          NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 4              0          NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN
#
#   UserNotes
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 58 columns]

# %%
df_lego_inicial
# Out:
#        SetID     Number  Variant  YearFrom Category                   Theme  \
# 0      22667          1        1      1965   Normal               Samsonite
# 1      22683          1        3      1967   Normal               Samsonite
# 2       7465          1        7      1973   Normal  Universal Building Set
# 3       7693          1        8      1970   Normal               Minitalia
# 4      22697          1        9      1969   Normal                  System
# ...      ...        ...      ...       ...      ...                     ...
# 21336  29327      XWING        1      2019    Other               Star Wars
# 21337  22978       YODA        1      2013    Other               Star Wars
# 21338  22776  YODACHRON        1      2013    Other               Star Wars
# 21339  32477       YOTT        1      2022    Other           Miscellaneous
# 21340  28456   YTERRIER        1      2018    Other             Promotional
#
#           ThemeGroup       Subtheme                                 SetName  \
# 0            Vintage      Basic Set                                   Gears
# 1            Vintage      Basic Set  Promotional Set No. 1 (Kraft Velveeta)
# 2              Basic            NaN                               Basic Set
# 3            Vintage            NaN                         Small house set
# 4              Basic      Basic Set           Set No 1 - Quaker/Life Cereal
# ...              ...            ...                                     ...
# 21336       Licensed    Promotional                     Mini X-wing Fighter
# 21337       Licensed    Promotional          Yoda minifig, NY I Heart Torso
# 21338       Licensed    Promotional                        Holocron Chamber
# 21339  Miscellaneous            NaN                                   Tiger
# 21340  Miscellaneous  Miscellaneous                       Yorkshire Terrier
#
#       Image  ... WantedPriority  Unnamed: 49  Flag2  Flag3  Flag4 Flag5 Flag6  \
# 0         X  ...              0          NaN    NaN    NaN    NaN   NaN   NaN
# 1         X  ...              0          NaN    NaN    NaN    NaN   NaN   NaN
# 2         X  ...              0          NaN    NaN    NaN    NaN   NaN   NaN
# 3         X  ...              0          NaN    NaN    NaN    NaN   NaN   NaN
# 4       NaN  ...              0          NaN    NaN    NaN    NaN   NaN   NaN
# ...     ...  ...            ...          ...    ...    ...    ...   ...   ...
# 21336     X  ...              0          NaN    NaN    NaN    NaN   NaN   NaN
# 21337     X  ...              0          NaN    NaN    NaN    NaN   NaN   NaN
# 21338     X  ...              0          NaN    NaN    NaN    NaN   NaN   NaN
# 21339     X  ...              0          NaN    NaN    NaN    NaN   NaN   NaN
# 21340     X  ...              0          NaN    NaN    NaN    NaN   NaN   NaN
#
#        Flag7  Flag8 UserNotes
# 0        NaN    NaN       NaN
# 1        NaN    NaN       NaN
# 2        NaN    NaN       NaN
# 3        NaN    NaN       NaN
# 4        NaN    NaN       NaN
# ...      ...    ...       ...
# 21336    NaN    NaN       NaN
# 21337    NaN    NaN       NaN
# 21338    NaN    NaN       NaN
# 21339    NaN    NaN       NaN
# 21340    NaN    NaN       NaN
#
# [21341 rows x 58 columns]

# %%
# Lista de temas elegidos para el proyecto
selected_themes = [
    'Animal Crossing', 'Architecture', 'Art',
    'Avatar: The Last Airbender', 'Avatar',
    'The LEGO Batman Movie', 'Batman', 'Botanicals',
    'BrickHeadz', 'World City', 'City', 'Classic',
    'Creator', 'Creator Expert', 'DC Super Hero Girls', 'DC Comics Super Heroes',
    'Despicable Me', 'Disney', 'Dots', 'Dreamzzz', 'DREAMZzz',
    'Duplo', 'Education', 'Friends', 'Fortnite', "Gabby's Dollhouse",
    'Harry Potter', 'Icons', 'Ideas', 'Indiana Jones', 'Jurassic World',
    'The Lord of the Rings', 'Marvel Super Heroes', 'Minecraft',
    'Collectable Minifigures', 'Monkie Kid', 'The LEGO Ninjago Movie', 'Ninjago',
    'Powered Up', 'Serious Play', 'Sonic the Hedgehog', 'Speed Champions',
    'Spider-Man', 'Star Wars', 'Super Mario', 'Technic', 'The Legend of Zelda',
    'Wednesday', 'Wicked',
]

# %%
# Filtro el dataset para que solo contenga las filas de los temas seleccionados
df_lego_work = df_lego_inicial[df_lego_inicial['Theme'].isin(selected_themes)]

# %%
df_lego_work
# Out:
#        SetID       Number  Variant  YearFrom Category      Theme  ThemeGroup  \
# 48      7530           10        2      1973   Normal      Duplo  Pre-school
# 71      7531           20        2      1973   Normal      Duplo  Pre-school
# 81      1119           28        1      1979   Normal      Duplo  Pre-school
# 85      7532           30        2      1973   Normal      Duplo  Pre-school
# 87      1382           32        1      1979   Normal      Duplo  Pre-school
# ...      ...          ...      ...       ...      ...        ...         ...
# 21328  22656  WISHINGWELL        1      2013    Other    Friends  Modern day
# 21335  30208        XWING        2      2019    Other  Star Wars    Licensed
# 21336  29327        XWING        1      2019    Other  Star Wars    Licensed
# 21337  22978         YODA        1      2013    Other  Star Wars    Licensed
# 21338  22776    YODACHRON        1      2013    Other  Star Wars    Licensed
#
#           Subtheme                         SetName Image  ... WantedPriority  \
# 48             NaN                  Pre-School Set   NaN  ...              0
# 71             NaN                    Building Set   NaN  ...              0
# 81             NaN               Nursery Furniture     X  ...              0
# 85             NaN                    Building Set   NaN  ...              0
# 87             NaN           Living Room Furniture     X  ...              0
# ...            ...                             ...   ...  ...            ...
# 21328  Promotional                    Wishing Well     X  ...              0
# 21335  Promotional               X-wing Trench Run     X  ...              0
# 21336  Promotional             Mini X-wing Fighter     X  ...              0
# 21337  Promotional  Yoda minifig, NY I Heart Torso     X  ...              0
# 21338  Promotional                Holocron Chamber     X  ...              0
#
#        Unnamed: 49  Flag2  Flag3  Flag4 Flag5 Flag6  Flag7  Flag8 UserNotes
# 48             NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN       NaN
# 71             NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN       NaN
# 81             NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN       NaN
# 85             NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN       NaN
# 87             NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN       NaN
# ...            ...    ...    ...    ...   ...   ...    ...    ...       ...
# 21328          NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN       NaN
# 21335          NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN       NaN
# 21336          NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN       NaN
# 21337          NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN       NaN
# 21338          NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN       NaN
#
# [9205 rows x 58 columns]

# %%
columns_to_drop = ['Own', 'Want', 'Unnamed: 49', 'Flag2', 'Flag3', 'Flag4', 'Flag5', 'Flag6', 'Flag7', 'Flag8', 'UserNotes',"Variant", "ThemeGroup", "EAN", "UPC", "UKRetailPrice",
    'QtyOwned','QtyOwnedNew','QtyOwnedUsed','QtyWanted','WantedPriority',"CARetailPrice", "DERetailPrice", "AdditionalImageCount", "InstructionsCount","USDateAdded", "USDateRemoved", "Designers", "Image", "USItemNumber", "EUItemNumber"]
df_lego_work = df_lego_work.drop(columns=columns_to_drop)

# %%
df_lego_work.to_csv("df_lego_work.csv", index=False)

# %%
df_lego_work
# Out:
#        SetID       Number  YearFrom Category      Theme     Subtheme  \
# 48      7530           10      1973   Normal      Duplo          NaN
# 71      7531           20      1973   Normal      Duplo          NaN
# 81      1119           28      1979   Normal      Duplo          NaN
# 85      7532           30      1973   Normal      Duplo          NaN
# 87      1382           32      1979   Normal      Duplo          NaN
# ...      ...          ...       ...      ...        ...          ...
# 21328  22656  WISHINGWELL      2013    Other    Friends  Promotional
# 21335  30208        XWING      2019    Other  Star Wars  Promotional
# 21336  29327        XWING      2019    Other  Star Wars  Promotional
# 21337  22978         YODA      2013    Other  Star Wars  Promotional
# 21338  22776    YODACHRON      2013    Other  Star Wars  Promotional
#
#                               SetName  ImageFilename  USRetailPrice  Pieces  \
# 48                     Pre-School Set            NaN            NaN    17.0
# 71                       Building Set            NaN            NaN    25.0
# 81                  Nursery Furniture          028-1            NaN     7.0
# 85                       Building Set            NaN            NaN    29.0
# 87              Living Room Furniture          032-1            NaN    14.0
# ...                               ...            ...            ...     ...
# 21328                    Wishing Well  WISHINGWELL-1            NaN    28.0
# 21335               X-wing Trench Run        XWING-2            NaN    52.0
# 21336             Mini X-wing Fighter        XWING-1            NaN    60.0
# 21337  Yoda minifig, NY I Heart Torso         YODA-1            NaN     3.0
# 21338                Holocron Chamber    YODACHRON-1            NaN   408.0
#
#        ...  AgeMin AgeMax OwnCount  WantCount  Released  Rating  \
# 48     ...     NaN    NaN       16         22         X       0
# 71     ...     NaN    NaN       17         24         X       0
# 81     ...     NaN    NaN       50         31         X       0
# 85     ...     NaN    NaN       17         23         X       0
# 87     ...     NaN    NaN       69         27         X       0
# ...    ...     ...    ...      ...        ...       ...     ...
# 21328  ...     NaN    NaN      216        506         X       0
# 21335  ...     NaN    NaN      133        747         X       0
# 21336  ...     8.0    NaN      141        582         X       0
# 21337  ...     NaN    NaN      249       1967         X       4
# 21338  ...     NaN    NaN      209       1831         X       0
#
#        BrickLinkSoldPriceNew  BrickLinkSoldPriceUsed  LaunchDate  ExitDate
# 48                       NaN                     NaN         NaN       NaN
# 71                       NaN                     NaN         NaN       NaN
# 81                       NaN                   11.72         NaN       NaN
# 85                       NaN                     NaN         NaN       NaN
# 87                       NaN                   10.52         NaN       NaN
# ...                      ...                     ...         ...       ...
# 21328                    NaN                     NaN         NaN       NaN
# 21335                   14.7                   21.16         NaN       NaN
# 21336                    NaN                     NaN         NaN       NaN
# 21337                 2826.3                     NaN         NaN       NaN
# 21338                 4885.9                  320.00         NaN       NaN
#
# [9205 rows x 27 columns]
